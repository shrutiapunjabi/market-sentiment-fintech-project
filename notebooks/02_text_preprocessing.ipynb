# %%
import pandas as pd
import numpy as np
import re
import nltk

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ShrutiPunjabi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ShrutiPunjabi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ShrutiPunjabi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ShrutiPunjabi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
df=pd.read_csv("sp500_headlines_2008_2024.csv")
df['Date']=pd.to_datetime(df['Date'])
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18153 entries, 0 to 18152
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   18153 non-null  object
#  1   Date    18153 non-null  datetime64[ns]
#  2   CP      18153 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 425.6+ KB

# %%
stop_words = set(stopwords.words('english'))

finance_noise = {
    'said', 'say', 'says',
    'company', 'companies',
    'market', 'markets',
    'stock', 'stocks',
    'share', 'shares',
    'year', 'years'
}

# %%
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):
    # Lowercase
    text = text.lower()
    
    # Remove numbers & punctuation
    text = re.sub(r'[^a-z\s]', '', text)
    
    # Tokenize
    tokens = word_tokenize(text)
    
    # Remove stopwords & finance noise + lemmatize
    tokens = [
        lemmatizer.lemmatize(token)
        for token in tokens
        if token not in stop_words
        and token not in finance_noise
        and len(token) > 2
    ]
    
    return " ".join(tokens)
df['clean_title'] = df['Title'].apply(preprocess_text)
df[['Title', 'clean_title']].head(10)
df.to_csv("sp500_headlines_2008_2024.csv", index=False)
